# %%
# item
# key
# value
# update

x = {
    'name':'A',
    'age':45,
    'salary':200000
}

# %%
x
# Out:
# {'name': 'A', 'age': 45, 'salary': 200000}

# %%
type(x)
# Out:
# dict

# %%
# keys
x.keys()
# Out:
# dict_keys(['name', 'age', 'salary'])

# %%
x.values()
# Out:
# dict_values(['A', 45, 200000])

# %%
x.items()
# Out:
# dict_items([('name', 'A'), ('age', 45), ('salary', 200000)])

# %%
y = {
    'age':23
}

# %%
x.update(y)

# %%
x
# Out:
# {'name': 'A', 'age': 23, 'salary': 200000}

# %%
z = {
    'hobby':'music',

}

# %%
x.update(z)

# %%
x
# Out:
# {'name': 'A', 'age': 23, 'salary': 200000, 'hobby': 'music'}

# %%
z.update(x)

# %%
z
# Out:
# {'hobby': 'music', 'name': 'A', 'age': 23, 'salary': 200000}
