# %%
a = 10

# %%
print(a)
# Out:
# 10

# %%
a= 12
print(a)
# Out:
# 12

# %%
# type of DC

# 1. list
# 2. tuple
# 3. dict
# 4. set

# %%
# list----->   int,str
x = [12,34,67,89,33,90,25,78]

# %%
x
# Out:
# [12, 34, 67, 89, 33, 90, 25, 78]

# %%
type(x)
# Out:
# list

# %%
x = ['hello bhai','python','123','me']

# %%
x
# Out:
# ['hello bhai', 'python', '123', 'me']

# %%
type(x)
# Out:
# list

# %%
x = [112,89,6,'hello python','machine Learning','boy',34.5,78.2,True]

# %%
x
# Out:
# [112, 89, 6, 'hello python', 'machine Learning', 'boy', 34.5, 78.2, True]

# %%
type(x)
# Out:
# list

# %% [markdown]
# # slicing & indexing

# %%
x
# Out:
# [112, 89, 6, 'hello python', 'machine Learning', 'boy', 34.5, 78.2, True]

# %%
x[2]
# Out:
# 6

# %%
#wap to slice ml from x.
x[4]
# Out:
# 'machine Learning'

# %%
x[2]
# Out:
# 6

# %%
x[6]
# Out:
# 34.5

# %%
x[2:6]
# Out:
# [6, 'hello python', 'machine Learning', 'boy']

# %%
x[2:7]
# Out:
# [6, 'hello python', 'machine Learning', 'boy', 34.5]

# %%
x[2:7:2]
# Out:
# [6, 'machine Learning', 34.5]

# %%
x[0:]
# Out:
# [112, 89, 6, 'hello python', 'machine Learning', 'boy', 34.5, 78.2, True]

# %%
x[:4]
# Out:
# [112, 89, 6, 'hello python']

# %%
x[:]
# Out:
# [112, 89, 6, 'hello python', 'machine Learning', 'boy', 34.5, 78.2, True]

# %%
x[::2]
# Out:
# [112, 6, 'machine Learning', 34.5, True]

# %%
# Mutable or Immutable----->
x
# Out:
# [112, 89, 6, 'hello python', 'machine Learning', 'boy', 34.5, 78.2, True]

# %%
x[2] = False

# %%
x
# Out:
# [112, 89, False, 'hello python', 'machine Learning', 'boy', 34.5, 78.2, True]

# %%
# mutable/ changeable
# ordered way
# index
# duplicacy allowed.
