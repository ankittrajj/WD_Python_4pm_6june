# %%
# wap to add two numbers.
a = 1
b = 2
c = a+b
print(c)
# Out:
# 3

# %%
# -,*,/
# +,-,/,*------> Airthmetic operator
#wap to divide two numbers----->
a = 10
b = 5
c = a/b
print(c)
type(c)

# absolute answer.(interms of floating numbers.)
# Out:
# 2.0
# float

# %%
a = 10
b = 5
c = a//b
print(c)
# Out:
# 2

# %%
type(c)
# Out:
# int

# %%
# %-----> mod operator.
a = 11
b = 5
c = a%b
print(c)
# Out:
# 1

# %% [markdown]
# # User Input

# %%
x = input('Enter something')
print(x)
# Out:
# Enter somethinghtrsw6yjeue67ue5634567485@#%U^$^
# htrsw6yjeue67ue5634567485@#%U^$^

# %%
# wap to add two numbers with the help of uers input.

a = int(input("Enter the first number"))
b = int(input("Enter the second number"))
c = a+b
print(c)
# Out:
# Enter the first number1
# Enter the second number2
# 3

# %%
# concatenation
a = '1'
b = '2'
c = a+b
print(c)
# Out:
# 12

# %%
a = int(input("Enter the first number"))
b = int(input("Enter the second number"))
c = a+b
print(c)
# Out:
# Enter the first number1
# Enter the second number2
# 3

# %%
a = int(input("Enter the first number"))
b = input("Enter the second number")
c = a+b
print(c)
# Out:
# Enter the first number1
# Enter the second number2
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1192/4124912805.py in <module>
#       1 a = int(input("Enter the first number"))
#       2 b = input("Enter the second number")
# ----> 3 c = a+b
#       4 print(c)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
a = int(input("Enter the first number"))
b = float(input("Enter the second number"))
c = a+b
print(c)
# Out:
# Enter the first number1
# Enter the second number2.3
# 3.3

# %%
a = int(input("Enter the first number"))
b = float(input("Enter the second number"))
c = a+b
print(c)
# Out:
# Enter the first number1
# Enter the second number4
# 5.0

# %%
# >,<,>=,<=,==,!=  ----> cond op.
# condition-----> 

# syntax -----> if / else
# if condition:
#     print(msg)
# else:
#     print(msg)


age = 18
if age>18:
    print("Adult")
elif age == 18:
    print("Teenager")
else:
    print('Child')
# Out:
# Teenager

# %%
# A company decided to give bonus 
# of 5% to employee if his/her year of service is more than 5 years.

# Ask user for their salary and year of service and print the net bonus amount
# # 

salary = int(input("Enter your salary"))
year_of_service = int(input("Enter your year of service"))

if year_of_service>5:
    bonus = (salary*5)/100
    print("Bonus",bonus)
else:
    print('No bonus')
# Out:
# Enter your salary45000
# Enter your year of service8
# Bonus 2250.0
