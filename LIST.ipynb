# %%
num = 7
if num>1:
    for i in range(2,num):
        if num % i == 0 :
            print(num,"Not the prime number")
            break
            
        else:
            print(num,"Prime number")
else:
    print(num,"not prime number")
# Out:
# 7 Prime number
# 7 Prime number
# 7 Prime number
# 7 Prime number
# 7 Prime number

# %%
for i in range(1, 6) :
    for j in range(i) :
        print("*", end="") 
    print()
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(1,6):
    print(i*"*")
# Out:
# *
# **
# ***
# ****
# *****

# %%
a = 'mohit'
# o/p ----->'tihom'
# slicing

print(a[::-1])
# Out:
# tihom

# %%
a = 'bahuballi'
reverse = a[::-1]

# %%
print(reverse)
# Out:
# illabuhab

# %%
reverse
# Out:
# 'illabuhab'

# %%
# palindrome----->
# boy
# mam----> palindrome


x = 'nitin'
if x[::]==x[::-1]:
    print("Palindrome")
else:
    print("NP")
# Out:
# Palindrome

# %%
x = 'nitin'
y = ''
for i in x:
    y = i+y
if x == y :
    print("P")
else:
    print("NP")
# Out:
# P

# %%
a = 3
b = '* '
c = a*b
c
# Out:
# '* * * '

# %%
for i in range(1,6):
    print(i*" * ")
# Out:
#  *
#  *  *
#  *  *  *
#  *  *  *  *
#  *  *  *  *  *

# %% [markdown]
# # Data Collection

# %%
a = 10

# %%
# type of DC
# list
# tuple
# dict
# set

# int
a = [10,20,30,40,50]

# %%
print(a)
# Out:
# ['23', 'hello bhai', 'python']

# %%
type(a)
# Out:
# list

# %%
# str
a = ['23','hello bhai','python' ]

# %%
print(a)
# Out:
# ['23', 'hello bhai', 'python']

# %%
type(a)
# Out:
# list

# %%
x = [1,2,3,'hello python',True,56.4,78.9]

# %%
x
# Out:
# [1, 2, 3, 'hello python', True, 56.4, 78.9]

# %%
type(x)
# Out:
# list

# %%
len(x)
# Out:
# 7

# %%
x
# Out:
# [1, 2, 3, 'hello python', True, 56.4, 78.9]

# %%
# min & max
min(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4640/1695965406.py in <module>
#       1 # min & max
# ----> 2 min(x)
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
x = [45,56,9,23,0,-12]
min(x)
# Out:
# -12

# %%
max(x)
# Out:
# 56

# %% [markdown]
# # Slicing with index

# %%
x
# Out:
# [1, 2, 3, 'hello python', True, 56.4, 78.9]

# %%
x[0]
# Out:
# 1

# %%
x[3]
# Out:
# 'hello python'

# %%
#range- function
