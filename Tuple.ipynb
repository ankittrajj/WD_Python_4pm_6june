# %%
#wap to make an empty list.
# #wap to make a single element list.

x = []
x
# Out:
# []

# %%
type(x)
# Out:
# list

# %%
x = [ 'python']

# %%
x
# Out:
# ['python']

# %%
type(x)
# Out:
# list

# %% [markdown]
# # Tuple

# %%
# list-----> 90 % tuple
# list & tuple are almost excatly the same.

# tuple of int
x = ( 1,2,5,8,0,9,3 )

# %%
x
# Out:
# (1, 2, 5, 8, 0, 9, 3)

# %%
type(x)
# Out:
# tuple

# %%
# tuple of string
x = ('python','hello','system')

# %%
x
# Out:
# ('python', 'hello', 'system')

# %%
type(x)
# Out:
# tuple

# %%
# 3.
a = (1,2,3,1,2,3)

# %%
a
# Out:
# (1, 2, 3, 1, 2, 3)

# %%
a = (1,2,3,'Hello',4,5,9,34.4,6,0,True,'Python')

# %%
a
# Out:
# (1, 2, 3, 'Hello', 4, 5, 9, 34.4, 6, 0, True, 'Python')

# %%
type(a)
# Out:
# tuple

# %%
# duplicacy is allowed in tuple.

# %%
# slicing with the help of index.

# %%
#wap to slice a data ie 3 from the tuple.
a[2]
# Out:
# 3

# %%
a(2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11092/2884796381.py in <module>
# ----> 1 a(2)
#
# TypeError: 'tuple' object is not callable

# %%
# index -----> ordered way
# slicing possible
a
# Out:
# (1, 2, 3, 'Hello', 4, 5, 9, 34.4, 6, 0, True, 'Python')

# %% [markdown]
# # Muttable or Immutable

# %%
a
# Out:
# (1, 2, 3, 'Hello', 4, 5, 9, 34.4, 6, 0, True, 'Python')

# %%
a[3]=100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11092/1334018548.py in <module>
# ----> 1 a[3]=100
#
# TypeError: 'tuple' object does not support item assignment

# %%
# tuple ----> immutable


a = (1, 2, 3, 'Hello', [4, 5, 9, 34.4, 6] ,0, True, 'Python')

# %%
a
# Out:
# (1, 2, 3, 'Hello', [4, 5, 9, 34.4, 6], 0, True, 'Python')

# %%
type(a)
# Out:
# tuple

# %%
x = [12,45,89,78,45,(1, 2, 3, 'Hello')]

# %%
x
# Out:
# [12, 45, 89, 78, 45, (1, 2, 3, 'Hello')]

# %%
type(x)
# Out:
# list

# %%
a
# Out:
# (1, 2, 3, 'Hello', [4, 5, 9, 34.4, 6], 0, True, 'Python')

# %%
a[7]
# Out:
# 'Python'

# %%
a[4][2]
# Out:
# 9

# %%
a
# Out:
# (1, 2, 3, 'Hello', [4, 5, 9, 34.4, 6], 0, True, 'Python')

# %%
a[3]=0
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11092/965836817.py in <module>
# ----> 1 a[3]=0
#
# TypeError: 'tuple' object does not support item assignment

# %%
a[4][2]=0

# %%
a
# Out:
# (1, 2, 3, 'Hello', [4, 5, 0, 34.4, 6], 0, True, 'Python')

# %%
a = 1, 2, 3, 'Hello', 0, True, 'Python'

# %%
a
# Out:
# (1, 2, 3, 'Hello', 0, True, 'Python')

# %%
type(a)
# Out:
# tuple

# %%
# tuple method
# index
# count
a
# Out:
# (1, 2, 3, 'Hello', 0, True, 'Python')

# %%
a.index(0)
# Out:
# 4

# %%
a.index(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11092/787977488.py in <module>
# ----> 1 a.index(100)
#
# ValueError: tuple.index(x): x not in tuple

# %%
a
# Out:
# (1, 2, 3, 'Hello', 0, True, 'Python')

# %%
a.count(0)
# Out:
# 1

# %%
a.count(1)
# Out:
# 2

# %%
a.count(2)
# Out:
# 1

# %%
a.count(3)
# Out:
# 1

# %%
a.count(5)
# Out:
# 0

# %%
a = (False,1, 2, 3, 'Hello', 0, True, 'Python')

# %%
a
# Out:
# (False, 1, 2, 3, 'Hello', 0, True, 'Python')

# %%
a.count(0)
# Out:
# 2

# %%
#wap to create empty tuple.
#wap to create single element tuple.
a = ()
print(a)
# Out:
# ()

# %%
type(a)
# Out:
# tuple

# %%
a = ('45',)
print(a)
# Out:
# ('45',)

# %%
type(a)
# Out:
# tuple

# %%
# min,max,sum,add
a = [45,67,89,34,6,53,122]
greatest_num = a[0]
for i in a:
    if i>greatest_num:
        greatest_num = i
        
print(greatest_num)
# Out:
# 122

# %%
type(i)
# Out:
# int

# %%
type(a)
# Out:
# list
