# %%
# wap to create a empty dict.
#wap to create a single element dict.
z = {
    'hobby':'music',

}

# %%
type(z)
# Out:
# dict

# %%
x = {
    
}

# %%
type(x)
# Out:
# dict

# %% [markdown]
# # SET

# %%
# create the set
x = {1,2,3,4}

# %%
x
# Out:
# {1, 2, 3, 4}

# %%
type(x)
# Out:
# set

# %%
x = {
    
}

# %%
type(x)
# Out:
# dict

# %%
s = {"123","hello","python"}

# %%
s
# Out:
# {'123', 'hello', 'python'}

# %%
type(s)
# Out:
# set

# %%
x = {"123","hello","python",67,89,34.9,45.3,True}

# %%
x
# Out:
# {'123', 34.9, 45.3, 67, 89, True, 'hello', 'python'}

# %%
# unordered,unidexed,slicing not possible,immutable,duplicacy is not allowed.

x = {45,90,23,0,-1,"True",True,90}

# %%
x
# Out:
# {-1, 0, 23, 45, 90, True, 'True'}

# %%
x = {34,34,34,34,56}
x
# Out:
# {34, 56}

# %%
# wap to create a empty set & single element set.
# add
# copy
# remove
# pop

a = {1}
a
# Out:
# {1}

# %%
type(a)
# Out:
# set

# %%
a = {''}
a
# Out:
# {''}

# %%
type(a)
# Out:
# set

# %%
a = set()
a
# Out:
# set()

# %%
type(a)
# Out:
# set

# %%
# add
# copy
# remove
# pop

x.add(1000)

# %%
x
# Out:
# {0, 10, 1000, '123', 34.9, 45.3, 67, 89, True, 'hello', 'python'}

# %%
# copy
y = x.copy()

# %%
y
# Out:
# {0, 10, 1000, '123', 34.9, 45.3, 67, 89, True, 'hello', 'python'}

# %%
x
# Out:
# {0, 10, 1000, '123', 34.9, 45.3, 67, 89, True, 'hello', 'python'}

# %%
x.remove(0)

# %%
x
# Out:
# {10, 1000, '123', 34.9, 45.3, 67, 89, True, 'hello', 'python'}

# %%
x.remove(34)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4184/1547375274.py in <module>
# ----> 1 x.remove(34)
#
# KeyError: 34

# %%
# pop
x
# Out:
# {10, 1000, '123', 34.9, 45.3, 67, 89, True, 'hello', 'python'}

# %%
x.pop()
# Out:
# True

# %%
x
# Out:
# {10, 1000, '123', 34.9, 45.3, 67, 89, 'hello', 'python'}

# %%
x.pop()
# Out:
# '123'

# %%
x
# Out:
# {10, 1000, 34.9, 45.3, 67, 89, 'hello', 'python'}

# %%
x.pop()
# Out:
# 67

# %%
x
# Out:
# {10, 1000, 34.9, 45.3, 89, 'hello', 'python'}

# %%
x
# Out:
# {10, 1000, 34.9, 45.3, 89, 'hello', 'python'}

# %%
x = {10, 1000,[ 34.9, 45.3, 89], 'hello', 'python'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_4184/1879042399.py in <module>
# ----> 1 x = {10, 1000,[ 34.9, 45.3, 89], 'hello', 'python'}
#
# TypeError: unhashable type: 'list'

# %%
x = {10, 1000,(34.9, 45.3, 89), 'hello', 'python'}

# %%
x
# Out:
# {(34.9, 45.3, 89), 10, 1000, 'hello', 'python'}
