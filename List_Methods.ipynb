# %%
#wap to estimate the salary of the emp.if the emp category 
# is of lower than 
# B then the salary will be in between 15-25k and if the 
# category of the 
# emp is 
# A the salary would be 40k .
# if your emp is taking less than 5 leaves in a year 
# then the bonus with salary will
# be given to the emp.
# if emp is in lower category then bonus will be 3% 
# if emp is in higher category the bonus will be 20%.

# %%
# a = int(input("Enter the salary"))
if a>=25000:
    b = (a*20)/100
    print(b)
else:
    b = (a*3)/100
    print(b)

# %%
employe=input("enter your category(A/B): ")
salary=int(input("enter your salary: "))
leaves=int(input("enter the no. of leaves taken: "))
if employe=="A":
    if leaves<=5:
        bonus=(salary*20)/100
        print("Your bonus amount is:",bonus)
    else:
        print("no bonus")
elif employe=="B":
    if leaves<=5:
        bonus=(salary*3)/100
        print("Your bonus amount is:",bonus)
    else:
        print("no bonus")
# Out:
# enter your category(A/B): 1
# enter your salary: 1
# enter the no. of leaves taken: 1

# %%
#wap to estimate the salary of the emp.if the emp category 
# is of lower than 
# A then the salary will be in between 15-25k and if the 
# category of the 
# emp is 
# A the salary would be 40k .
# if your emp is taking less than 5 leaves in a year 
# then the bonus with salary will
# be given to the emp.
# if emp is in lower category then bonus will be 3% 
# if emp is in higher category the bonus will be 20%.

salary = int(input("Enter the salary"))
category=input("Enter the category A/B")
leave = int(input("Enter your number of leaves"))

if category == 'A'and leave<5:
    bonus = (salary*20)/100
    total_sal = salary+bonus
    print(total_sal)
else:
    bonus_CB = (salary*3)/100
    total_sal_CB = salary+bonus_CB
    print(total_sal_CB)
# Out:
# Enter the salary1
# Enter the category A/B1
# Enter your number of leaves1
# 1.03

# %%
# a = input("Enter your catagory(A/B)")
# x = int(input("Enter your slary"))
# b = int(input("Enter your number of leaves"))
# c = x*3/100
# d = x*20/100
# e = x + c
# f = x + d
# if a == 'A' and b<5:
#     print("your salary is"(f))
# elif a == A and b>5:
#       print("your salary is"(x))  
# elif a == B and b<5:
#       print("your salary is"(e))  
# else:
#       print("your salary is"(x))  1

# %%
#wap to print fizz & buzz.
# if  your number is divisible by 5 then print fizz.
# if your number is divisible by 3 then print buzz.
# if your number is both divisible by\
# 5 & 3 then print fizzbuzz.

# take number from 0-30.
num = int(input("Enter the range"))
for i in range(num):
    if i % 5 == 0 and i % 3 == 0:
        print('fizz------buzz',i)
    elif i % 3 == 0:
        print("buzz",i)
    elif i % 5 == 0: 
        print("fizz",i)
# Out:
# Enter the range61
# fizz------buzz 0
# buzz 3
# fizz 5
# buzz 6
# buzz 9
# fizz 10
# buzz 12
# fizz------buzz 15
# buzz 18
# fizz 20
# buzz 21
# buzz 24
# fizz 25
# buzz 27
# fizz------buzz 30
# buzz 33
# fizz 35
# buzz 36
# buzz 39
# fizz 40
# buzz 42
# fizz------buzz 45
# buzz 48
# fizz 50
# buzz 51
# buzz 54
# fizz 55
# buzz 57
# fizz------buzz 60

# %%
# list----->
num = int(input("Enter range"))
for i in range(num):
    if i % 5 == 0 and i % 3 == 0:
        print('fizzbuzz',i)
    elif i % 3 == 0:
        print('buzz',i)  
    elif i % 5 == 0:
        print('fizz',i)
# Out:
# Enter range45
# fizzbuzz 0
# buzz 3
# fizz 5
# buzz 6
# buzz 9
# fizz 10
# buzz 12
# fizzbuzz 15
# buzz 18
# fizz 20
# buzz 21
# buzz 24
# fizz 25
# buzz 27
# fizzbuzz 30
# buzz 33
# fizz 35
# buzz 36
# buzz 39
# fizz 40
# buzz 42

# %%
# list
x = [78,45,78,34,90,0]

# %%
x
# Out:
# [78, 45, 78, 34, 90, 0]

# %%
# mutable & immutable 
# list is mutable.
x[0]=87

# %%
x
# Out:
# [87, 45, 78, 34, 90]

# %%
# list method
# append
# remove
# insert
# pop
# count

x
# Out:
# [87, 45, 78, 34, 90]

# %%
x.append(0)

# %%
x
# Out:
# [78, 45, 78, 34, 90, 0, 0]

# %%
x.append('shabad')

# %%
x
# Out:
# [78, 45, 78, 34, 90, 0, 0, 'shabad']

# %%
# count
x.count(46)
# Out:
# 0

# %%
x.count(0)
# Out:
# 2

# %%
x.count(34)
# Out:
# 1

# %%
# insert
x.insert(0,10)

# %%
x
# Out:
# [10, 78, 45, 78, 34, 90, 0, 0, 'shabad']

# %%
# pop
# remove
x.pop()
# Out:
# 'shabad'

# %%
x.pop(0)
# Out:
# 10

# %%
x
# Out:
# [78, 45, 78, 34, 90, 0, 0]

# %%
x.remove(45)

# %%
x
# Out:
# [78, 78, 34, 90, 0, 0]

# %%
# insert
x=[1,2,3]

# %%
x
# Out:
# [1, 2, 3]

# %%
x.insert(1,6)

# %%
x
# Out:
# [1, 6, 2, 3]
