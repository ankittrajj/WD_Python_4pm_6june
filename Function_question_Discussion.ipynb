# %%
#wap to check a string is reversed or not?
# Write a function to check a string is palindrome or not?
#Wap to sum the first 10 natural numbers using function?

a = 'python'
b = a[::-1]
if a == b:
    print("Not revese")
else:
    print(" reverse")
    
print(b)
# Out:
#  reverse
# nohtyp

# %%
a = 'python'
b = a[::-1]
if a != b:
    print(" reverse")
else:
    print(" Not reverse")
    
print(b)
# Out:
#  revese
# nohtyp

# %%
def pal():
    a = 'apple'
    b = ''
    for i in a:
        b = i+b
        print(b)
    if a==b:
        print('P')
    else:
        print('NP')
        
pal()
# Out:
# a
# pa
# ppa
# lppa
# elppa
# NP

# %%
def fun(a,b):
    for i in a:
        b = b+i
    return b
a = [1,2,3,4]
fun(a,0)
# Out:
# 10

# %%
# 5 -----
# 80----> rupees
# avg price<> 350


# wap and try to print number from 1-50 if the number is divisible by 5
# then try to get the output as fizz and if the number is divisible by 3 
# then try to print buzz and also if the number is divisible by both 
# 5&3 try to print fizzbuzz.
# if the number is divisible by 3 but not by 2 then try to print great.

num = 50
for i in range(1,num+1):
    if i%5==0 and i%3==0:
        print("Fizz-Buzz----->",i)
    elif i%3==0 and i%2!=0:
        print("Great number------>",i)
    elif i%5==0:
        print(i,"Fizz")
    elif i%3==0:
        print(i,"------->Buzz")
# Out:
# Great number------> 3
# 5 Fizz
# 6 ------->Buzz
# Great number------> 9
# 10 Fizz
# 12 ------->Buzz
# Fizz-Buzz-----> 15
# 18 ------->Buzz
# 20 Fizz
# Great number------> 21
# 24 ------->Buzz
# 25 Fizz
# Great number------> 27
# Fizz-Buzz-----> 30
# Great number------> 33
# 35 Fizz
# 36 ------->Buzz
# Great number------> 39
# 40 Fizz
# 42 ------->Buzz
# Fizz-Buzz-----> 45
# 48 ------->Buzz
# 50 Fizz

# %% [markdown]
# # Default Arguments

# %%
# logical opertaor-----> and or    <,>,<=,>=,==,!=

def add(x=1,y=9):
    return x+y
add(9,1)
# Out:
# 10

# %%
add(2)
# Out:
# 11

# %%
add(,5)
# Out:
#   File "C:\Users\Satyam\AppData\Local\Temp/ipykernel_5684/692488989.py", line 1
#     add(,3)
#         ^
# SyntaxError: invalid syntax

# %%
add(2,-3)
# Out:
# -1

# %%
def add1(a=1,b,c=8):
    return a+b
add1(9,1)
# Out:
#   File "C:\Users\Satyam\AppData\Local\Temp/ipykernel_5684/2999752955.py", line 1
#     def add1(a=1,b):
#                   ^
# SyntaxError: non-default argument follows default argument

# %%
add1(2,3)
# Out:
# 5

# %%
add1(1)
# Out:
# 1

# %%
add1()
# Out:
# 1

# %%
# Wap to find out the average cost of 5 quantity each
# quantity is having the value of 80 and if the value exceed by
# avg value then also calculate the total price of whole quantity
# avg value => 350
def fun(quantity,each_price):
#     quantity = 5
#     each_price = 800
    total_price = quantity*each_price
    avg_price = total_price/quantity
    print(avg_price)
    
   

    if avg_price>=350:
        total_price = quantity*each_price
        print(total_price)
        
         
fun(5,800)
# Out:
# 800.0
# 4000
