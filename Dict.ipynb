# %%
# create a dict
# []
# ()
# {}

x = {
    'name':'A',
    'age':23,
    'marks':89
}

# %%
x
# Out:
# {'name': 'A', 'age': 23, 'marks': 89}

# %%
type(x)
# Out:
# dict

# %%
# dict-----> index,orderway.....
# slicing with indexing is not possible in dict

x
# Out:
# {'name': 'A', 'age': 23, 'marks': 89}

# %%
x[1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10484/4118936608.py in <module>
# ----> 1 x[1]
#
# KeyError: 1

# %%
x[3]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10484/2145826956.py in <module>
# ----> 1 x[3]
#
# KeyError: 3

# %%
# dict -----> slicing with the help of keys.
x
# Out:
# {'name': 'A', 'age': 23, 'marks': 89}

# %%
x['age']
# Out:
# 23

# %%
x['marks']
# Out:
# 89

# %%
x
# Out:
# {'name': 'A', 'age': 23, 'marks': 89}

# %%
x = {
    'name':['A','B','C'],
    'age':(23,21,22),
    'marks':(89,78,34)
}

# %%
x
# Out:
# {'name': ['A', 'B', 'C'], 'age': (23, 21, 22), 'marks': (89, 78, 34)}

# %%
type(x)
# Out:
# dict

# %%
x['name'][1]='billu'

# %%
x
# Out:
# {'name': ['A', 'billu', 'C'], 'age': (23, 21, 22), 'marks': (89, 78, 34)}

# %%
# dict ----> mutable or immutable??
x['name']='bahuballi'

# %%
x
# Out:
# {'name': 'bahuballi', 'age': (23, 21, 22), 'marks': (89, 78, 34)}

# %%
x = {
    'name':['A','B','C'],
    'age':(23,21,22),
    'marks':(89,78,34),
    'y':{
        'hobby':'music',
        'salary':45
    }
    
}
# wap to a dict inside a dict.

# %%
x
# Out:
# {'name': ['A', 'B', 'C'],
#  'age': (23, 21, 22),
#  'marks': (89, 78, 34),
#  'y': {'hobby': 'music', 'salary': 45}}

# %%
x = {
    'name':['A','B','C'],
    'age':(23,21,22),
    'marks':(89,78,34),
    0:1,
    1:[786,890],
    '0':'1',
    '0':1,
    0:'1',
    0:'hello bhai',
    'h':"0 op!!",
    
    
#     'y':{
#         'hobby':'music',
#         'salary':45
#     }
    
}

# %%
# duplicay not allowed in dict.
x
# Out:
# {'name': ['A', 'B', 'C'],
#  'age': (23, 21, 22),
#  'marks': (89, 78, 34),
#  0: 'hello bhai',
#  1: [786, 890],
#  '0': 1,
#  'h': '0 op!!'}

# %%
# dict---->
# items
# update
# key
# values


x = {
    'name':['A','B','C'],
    'age':(23,21,22),
    'marks':(89,78,34),
    
    'y':{
        '0':100
    }
}

# %%
x
# Out:
# {'name': ['A', 'B', 'C'],
#  'age': (23, 21, 22),
#  'marks': (89, 78, 34),
#  'y': {'0': 100}}
