# %%
print('hello world')
# Out:
# hello world

# %%
print("hello world")
# Out:
# hello world

# %%
print('Ram's book')
# Out:
#   File "C:\Users\Satyam\AppData\Local\Temp/ipykernel_912/3435484128.py", line 1
#     print('Ram's book')
#                ^
# SyntaxError: invalid syntax

# %%
print("Ram's book")
# Out:
# Ram's' book

# %%
print(Ram ' " Shyam)
# Out:
#   File "C:\Users\Satyam\AppData\Local\Temp/ipykernel_912/2419243103.py", line 1
#     print(Ram ' " Shyam)
#                         ^
# SyntaxError: EOL while scanning string literal

# %%
print('''bgdkagb
fkjbvgd''')
# Out:
# bgdkagb
# fkjbvgd

# %%
print('bhkdfbv
      khbvf')
# Out:
#   File "C:\Users\Satyam\AppData\Local\Temp/ipykernel_912/588110387.py", line 1
#     print('bhkdfbv
#                   ^
# SyntaxError: EOL while scanning string literal

# %%
print("vhjvbfk
      bkasxdf")
# Out:
#   File "C:\Users\Satyam\AppData\Local\Temp/ipykernel_912/2657539759.py", line 1
#     print("vhjvbfk
#                   ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# # Data Types & variables

# %%
# int------ +ve or -ve (0-9)
# float----->
# string
# boolean
# complex


x = -3
print(x)
# Out:
# -3

# %%
type(x)
# Out:
# int

# %%
x = -89.7
print(x)
# Out:
# -89.7

# %%
type(x)
# Out:
# float

# %%
print(123)
# Out:
# 123

# %%
print('123')
# Out:
# 123

# %%
a = 123
b = '123'
print(a)
# Out:
# 123

# %%
print(a)
# Out:
# 123

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# str

# %%
x = 'I^&$^&R*FYvyhjgswfdwfk))%%dfkugakdb467867854678578'

# %%
print(x)
# Out:
# I^&$^&R*FYvyhjgswfdwfk))%%dfkugakdb467867854678578

# %%
type(x)
# Out:
# str

# %%
# boolean
a = True
print(a)
type(a)
# Out:
# True
# bool

# %%
a = 'True'
print(a)
type(a)
# Out:
# True
# str

# %%
# complex
x = 3+7j
print(x)
# Out:
# (3+7j)

# %%
type(x)
# Out:
# complex
